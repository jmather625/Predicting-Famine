# %%
from skimage.external.tifffile import imread, imsave
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# !ls data_dump/
# Out:
# F182013.v4.tar
# F182013.v4c_web.avg_vis.tfw
# F182013.v4c_web.avg_vis.tif
# F182013.v4c_web.avg_vis.tif.gz
# F182013.v4c_web.cf_cvg.tfw
# F182013.v4c_web.cf_cvg.tif
# F182013.v4c_web.cf_cvg.tif.gz
# F182013.v4c_web.stable_lights.avg_vis.tfw
# F182013.v4c_web.stable_lights.avg_vis.tif
# F182013.v4c_web.stable_lights.avg_vis.tif.gz
# README_V4.txt

# %%
im = imread('data_dump/F182013.v4c_web.stable_lights.avg_vis.tif')

# %%
im.shape
# Out:
# (16801, 43201)

# %%
im.std()
# Out:
# 3.909449265298388

# %%
(im == 0).mean()
# Out:
# 0.9615086509582146

# %%
im2 = imread('data_dump/F182013.v4c_web.avg_vis.tif')

# %%
plt.imshow(im2[0:200,0:200])

# %%
im3 = imread('data_dump/F182013.v4c_web.cf_cvg.tif')

# %%
im3
# Out:
# array([[24, 24, 24, ..., 24, 24, 24],
#        [24, 24, 24, ..., 24, 24, 24],
#        [24, 24, 24, ..., 24, 24, 24],
#        ...,
#        [ 3,  3,  3, ...,  3,  3,  3],
#        [ 3,  3,  3, ...,  3,  3,  3],
#        [ 0,  0,  0, ...,  0,  0,  0]], dtype=uint8)

# %%
im3.max()
# Out:
# 124

# %%
plt.imshow(im3[0:200,0:200])

# %%
im.shape, im2.shape, im3.shape
# Out:
# ((16801, 43201), (16801, 43201), (16801, 43201))

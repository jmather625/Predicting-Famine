# %%
from PlanetDownloader import *

# %%
api_key = None
with open('api_key.txt') as f:
    api_key = f.readlines()[0].strip()

# %%
planet = PlanetDownloader(api_key)

# %%
lat = -16.983333
lon = 35.208332
min_year = 2016
min_month = 1 # January

max_year = 2016
max_month = 12 # December

# %%
planet.download_image(lat, lon, min_year, min_month, max_year, max_month)
# Out:
# https://tiles0.planet.com/data/v1/PSScene3Band/20161117_074232_0c56/14/9794/8976.png?api_key=37e4ea6a83ff4ab9953a259e3dc70e26
# <PIL.PngImagePlugin.PngImageFile image mode=P size=256x256 at 0x107D1CD68>

# %%
from PlanetDownloader import *

# %%
api_key = None
with open('api_key.txt') as f:
    api_key = f.readlines()[0]

# %%
planet = PlanetDownloader(api_key)

# %%
lat = -16.983333
lon = 35.208332
min_year = 2016
min_month = 1 # July

max_year = 2016
max_month = 12 # August

# %%
planet.download_image(lat, lon, min_year, min_month, max_year, max_month)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=256x256 at 0x7F47C317B6D0>
